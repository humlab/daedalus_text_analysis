# %% [markdown]
# # Daedalus Placename Analysis

# %% [markdown]
# ## Identify geographical locations using SWE-NER
# See [https://docs.google.com/document/d/1a7nJV-KX2H1Wr4K-5MmjX8-HIoGg-R9Ke3jADamZraQ/edit]

# %%
# %autosave 60
import pandas as pd
import geopandas                                    # HOWTO install: http://geoffboeing.com/2014/09/using-geopandas-windows/
from geopandas.tools import geocode                 # uses geopy
import geocoder as geocoder                         # alternative to geopy: pip install geocoder
from geopy.geocoders import GeoNames, Nominatim, GoogleV3     # if explicit use of geopy
import numpy as np
# Out:
# Autosaving every 60 seconds

# %% [markdown]
# ## Geocode locations
#
# 1. Load the NER data from file into a dataframe. (This data is the result data from running the SWE-NER software).
# 2. Filter out locations from the data (entities tagged as "LOC")
# 3. Filter out all unique locations
# 4. Geocode the unique locations
# 5. Apply the geocoded coordinates back to the location data
# 6. Create statistics!
# 7. Plot!
#
# The gecoding is done using the *geopy* library [https://github.com/geopy/geopy].

# %%
df = pd.read_fwf('Daedalus1931-79.tags.tsv', header=None, encoding='utf-8', names=['year', 'position', 'offset', 'category', 'subcategory', 'entity'])

# %%
dfloc = df.loc[df.category=='LOC',['year', 'entity']]
dfunique = dfloc['entity'].drop_duplicates().to_frame()
dfunique['processed'] = None
dfunique['latitude'] = np.nan
dfunique['longitude'] = np.nan
dfunique['reversename'] = np.nan
#dfunique = dfunique.drop('geocode',axis=1)

#df_year_count = df.groupby(['year', 'entity']).size().reset_index(name='counts')

# %%
dfunique.info()
dfunique.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2793 entries, 6 to 54504
# Data columns (total 5 columns):
# entity         2793 non-null object
# processed      0 non-null object
# latitude       0 non-null float64
# longitude      0 non-null float64
# reversename    0 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 210.9+ KB
#         entity processed  latitude  longitude  reversename
# 6         Wien      None       NaN        NaN          NaN
# 11       Norge      None       NaN        NaN          NaN
# 19     Sverige      None       NaN        NaN          NaN
# 20  Falu gruva      None       NaN        NaN          NaN
# 22       Falun      None       NaN        NaN          NaN

# %%
dfunique = dfunique.set_index('entity')

# %%
i = 0
geolocator = GoogleV3(api_key='AIzaSyAUPl7HOuaq1rF_PmMykx1G0JMjeNJZzBQ', timeout=5)
#geolocator = GeoNames(country_bias='Sweden', username='humlab')
#geolocator = Nominatim() # OpenStreetMaps

#dfunique['processed'] = None

for index, row in dfunique.iterrows():
    
    if not row['processed'] is None:
        continue
        
    dfunique.loc[index,'processed'] = True        
    location = geolocator.geocode(index) # dfunique.loc[index,'entity'])
    
    if not location is None:
        dfunique.loc[index,'latitude'] = location.latitude
        dfunique.loc[index,'longitude'] = location.longitude
        
        point = [ location.latitude, location.longitude ]
    
        reverseName = geolocator.reverse(point, exactly_one=True)
        
        if not reverseName is None:
            # print("{0} ==> {1}".format(row['entity'], reverseName[0]))
            print("{0} ==> {1}".format(index, reverseName[0]))
            dfunique.loc[index,'reversename'] = reverseName[0]
    
    if i > 50:
        break
    i += 1
    
writer = pd.ExcelWriter('C:\TEMP\daedalus_ner_geocoded_NEW.xlsx')
dfunique.to_excel(writer,'Sheet1')
writer.save()

# %%
writer = pd.ExcelWriter('C:\TEMP\daedalus_ner_geocoded_NEW13.xlsx')
dfunique.to_excel(writer,'Sheet1')
writer.save()

# %%
dfu = pd.read_excel(open('C:\TEMP\daedalus_ner_geocoded_NEW13.xlsx','rb'), sheetname='Sheet1',index='entity')
dfu = dfu.set_index('entity')

map(lambda x: x == 1.0, dfu['processed'])

# %%
dfu.loc[(dfu['processed']!=1.0)]
# Out:
#                                processed  latitude  longitude reversename
# entity
# St Pauls                             NaN       NaN        NaN         NaN
# City of London                       NaN       NaN        NaN         NaN
# Halvvägs                             NaN       NaN        NaN         NaN
# Peterskyrkan                         NaN       NaN        NaN         NaN
# Östafrika                            NaN       NaN        NaN         NaN
# Medelhavsområdet                     NaN       NaN        NaN         NaN
# Rom,                                 NaN       NaN        NaN         NaN
# Wien. Vid Wallensteins               NaN       NaN        NaN         NaN
# Västerviks                           NaN       NaN        NaN         NaN
# Söderhamns                           NaN       NaN        NaN         NaN
# Saint Paul                           NaN       NaN        NaN         NaN
# Wira Bruk                            NaN       NaN        NaN         NaN
# Wira,                                NaN       NaN        NaN         NaN
# Jungfrugatan 6                       NaN       NaN        NaN         NaN
# Schweidnitz                          NaN       NaN        NaN         NaN
# krigsmuseet                          NaN       NaN        NaN         NaN
# Upplands Väsby                       NaN       NaN        NaN         NaN
# Korsberga                            NaN       NaN        NaN         NaN
# Vintrosa                             NaN       NaN        NaN         NaN
# Tekniska Elementarskolan             NaN       NaN        NaN         NaN
# Hälsingegatan                        NaN       NaN        NaN         NaN
# Sturehof                             NaN       NaN        NaN         NaN
# Galcos lokaler                       NaN       NaN        NaN         NaN
# Kullagerfabriken                     NaN       NaN        NaN         NaN
# Galco-fabriken                       NaN       NaN        NaN         NaN
# USA. Efter                           NaN       NaN        NaN         NaN
# Olofström                            NaN       NaN        NaN         NaN
# Ernst Grauers lokaler                NaN       NaN        NaN         NaN
# Volvo-fabriken                       NaN       NaN        NaN         NaN
# Riihimäki                            NaN       NaN        NaN         NaN
# ...                                  ...       ...        ...         ...
# öregrund                             NaN       NaN        NaN         NaN
# Skärplinge                           NaN       NaN        NaN         NaN
# Åkerby bruk                          NaN       NaN        NaN         NaN
# Löfsta                               NaN       NaN        NaN         NaN
# Harnäsviken                          NaN       NaN        NaN         NaN
# Mörkö                                NaN       NaN        NaN         NaN
# Hasslö                               NaN       NaN        NaN         NaN
# Falsterbo                            NaN       NaN        NaN         NaN
# Norrlandskusten                      NaN       NaN        NaN         NaN
# Upplandskusten                       NaN       NaN        NaN         NaN
# General Electrics forskningsl        NaN       NaN        NaN         NaN
# Schenectady. Hans                    NaN       NaN        NaN         NaN
# WGY-studion                          NaN       NaN        NaN         NaN
# General Electrics laboratoriu        NaN       NaN        NaN         NaN
# Huvudgatan                           NaN       NaN        NaN         NaN
# Bochum                               NaN       NaN        NaN         NaN
# Västtyskland                         NaN       NaN        NaN         NaN
# Ludvika. Exkursioner                 NaN       NaN        NaN         NaN
# Karlsholmsbruk                       NaN       NaN        NaN         NaN
# Loka brunn                           NaN       NaN        NaN         NaN
# Dalarnas museum                      NaN       NaN        NaN         NaN
# PPL/HUM\tAlbany                      NaN       NaN        NaN         NaN
# Mark                                 NaN       NaN        NaN         NaN
# ROM                                  NaN       NaN        NaN         NaN
# Infotech State                       NaN       NaN        NaN         NaN
# PPL/HUM\tNyborg                      NaN       NaN        NaN         NaN
# Santa Clara                          NaN       NaN        NaN         NaN
# Hallwylska palatset                  NaN       NaN        NaN         NaN
# PPL/CRP\tPerstorps                   NaN       NaN        NaN         NaN
# Hässelby                             NaN       NaN        NaN         NaN
#
# [116 rows x 4 columns]

# %%
dfu
# Out:
#                                                         processed   latitude  \
# entity
# Wien                           <map object at 0x000001DC357A0A20>  48.208174
# Norge                          <map object at 0x000001DC357A0A20>  60.472024
# Sverige                        <map object at 0x000001DC357A0A20>  60.128161
# Falu gruva                     <map object at 0x000001DC357A0A20>  60.600216
# Falun                          <map object at 0x000001DC357A0A20>  60.606460
# Lesjöfors                      <map object at 0x000001DC357A0A20>  59.977054
# Garphyttan                     <map object at 0x000001DC357A0A20>  59.303709
# Gunnebo                        <map object at 0x000001DC357A0A20>  57.720821
# Sveriges                       <map object at 0x000001DC357A0A20>  60.128161
# Tabergs                        <map object at 0x000001DC357A0A20>  57.677732
# Värmland                       <map object at 0x000001DC357A0A20>  59.729407
# Grängesberg                    <map object at 0x000001DC357A0A20>  60.078555
# Adolf Fredriks skrädhus        <map object at 0x000001DC357A0A20>        NaN
# Stora Kopparbergs              <map object at 0x000001DC357A0A20>  60.614445
# Finspångs                      <map object at 0x000001DC357A0A20>  58.832823
# Berga                          <map object at 0x000001DC357A0A20>  50.748625
# Malmö                          <map object at 0x000001DC357A0A20>  55.604981
# Stortägtsgruvan                <map object at 0x000001DC357A0A20>        NaN
# Strömsholms                    <map object at 0x000001DC357A0A20>  59.527589
# Lund                           <map object at 0x000001DC357A0A20>  55.704660
# Finspång                       <map object at 0x000001DC357A0A20>  58.707488
# Tyskland                       <map object at 0x000001DC357A0A20>  51.165691
# Norden                         <map object at 0x000001DC357A0A20>  39.317356
# Leipzig                        <map object at 0x000001DC357A0A20>  51.339695
# Åmmeberg                       <map object at 0x000001DC357A0A20>  58.865750
# Närke                          <map object at 0x000001DC357A0A20>  58.670196
# Timsälven                      <map object at 0x000001DC357A0A20>        NaN
# Sala gruva                     <map object at 0x000001DC357A0A20>  59.907230
# Sandvikens                     <map object at 0x000001DC357A0A20>  66.625915
# Rejmyre                        <map object at 0x000001DC357A0A20>  58.829285
# ...                                                           ...        ...
# öregrund                       <map object at 0x000001DC357A0A20>        NaN
# Skärplinge                     <map object at 0x000001DC357A0A20>        NaN
# Åkerby bruk                    <map object at 0x000001DC357A0A20>        NaN
# Löfsta                         <map object at 0x000001DC357A0A20>        NaN
# Harnäsviken                    <map object at 0x000001DC357A0A20>        NaN
# Mörkö                          <map object at 0x000001DC357A0A20>        NaN
# Hasslö                         <map object at 0x000001DC357A0A20>        NaN
# Falsterbo                      <map object at 0x000001DC357A0A20>        NaN
# Norrlandskusten                <map object at 0x000001DC357A0A20>        NaN
# Upplandskusten                 <map object at 0x000001DC357A0A20>        NaN
# General Electrics forskningsl  <map object at 0x000001DC357A0A20>        NaN
# Schenectady. Hans              <map object at 0x000001DC357A0A20>        NaN
# WGY-studion                    <map object at 0x000001DC357A0A20>        NaN
# General Electrics laboratoriu  <map object at 0x000001DC357A0A20>        NaN
# Huvudgatan                     <map object at 0x000001DC357A0A20>        NaN
# Bochum                         <map object at 0x000001DC357A0A20>        NaN
# Västtyskland                   <map object at 0x000001DC357A0A20>        NaN
# Ludvika. Exkursioner           <map object at 0x000001DC357A0A20>        NaN
# Karlsholmsbruk                 <map object at 0x000001DC357A0A20>        NaN
# Loka brunn                     <map object at 0x000001DC357A0A20>        NaN
# Dalarnas museum                <map object at 0x000001DC357A0A20>        NaN
# PPL/HUM\tAlbany                <map object at 0x000001DC357A0A20>        NaN
# Mark                           <map object at 0x000001DC357A0A20>        NaN
# ROM                            <map object at 0x000001DC357A0A20>        NaN
# Infotech State                 <map object at 0x000001DC357A0A20>        NaN
# PPL/HUM\tNyborg                <map object at 0x000001DC357A0A20>        NaN
# Santa Clara                    <map object at 0x000001DC357A0A20>        NaN
# Hallwylska palatset            <map object at 0x000001DC357A0A20>        NaN
# PPL/CRP\tPerstorps             <map object at 0x000001DC357A0A20>        NaN
# Hässelby                       <map object at 0x000001DC357A0A20>        NaN
#
#                                 longitude  \
# entity
# Wien                            16.373819
# Norge                            8.468946
# Sverige                         18.643501
# Falu gruva                      15.616582
# Falun                           15.635500
# Lesjöfors                       14.184545
# Garphyttan                      14.945119
# Gunnebo                         16.526140
# Sveriges                        18.643501
# Tabergs                         14.087904
# Värmland                        13.235402
# Grängesberg                     15.011062
# Adolf Fredriks skrädhus               NaN
# Stora Kopparbergs               15.629533
# Finspångs                       15.748953
# Berga                           12.161509
# Malmö                           13.003822
# Stortägtsgruvan                       NaN
# Strömsholms                     16.238346
# Lund                            13.191007
# Finspång                        15.773595
# Tyskland                        10.451526
# Norden                        -120.354182
# Leipzig                         12.373075
# Åmmeberg                        14.999516
# Närke                           16.934901
# Timsälven                             NaN
# Sala gruva                      16.575974
# Sandvikens                      16.218012
# Rejmyre                         15.931798
# ...                                   ...
# öregrund                              NaN
# Skärplinge                            NaN
# Åkerby bruk                           NaN
# Löfsta                                NaN
# Harnäsviken                           NaN
# Mörkö                                 NaN
# Hasslö                                NaN
# Falsterbo                             NaN
# Norrlandskusten                       NaN
# Upplandskusten                        NaN
# General Electrics forskningsl         NaN
# Schenectady. Hans                     NaN
# WGY-studion                           NaN
# General Electrics laboratoriu         NaN
# Huvudgatan                            NaN
# Bochum                                NaN
# Västtyskland                          NaN
# Ludvika. Exkursioner                  NaN
# Karlsholmsbruk                        NaN
# Loka brunn                            NaN
# Dalarnas museum                       NaN
# PPL/HUM\tAlbany                       NaN
# Mark                                  NaN
# ROM                                   NaN
# Infotech State                        NaN
# PPL/HUM\tNyborg                       NaN
# Santa Clara                           NaN
# Hallwylska palatset                   NaN
# PPL/CRP\tPerstorps                    NaN
# Hässelby                              NaN
#
#                                                                      reversename
# entity
# Wien                                                                         NaN
# Norge                                           Unnamed Road, 3580 Geilo, Norway
# Sverige                                      Gruvvägen 2, 760 49 Herräng, Sweden
# Falu gruva                                   GRUVPLATSEN 5, 791 61 Falun, Sweden
# Falun                                  Bergmästaregatan 11, 791 30 Falun, Sweden
# Lesjöfors                                  Parkgatan 9, 680 96 Lesjöfors, Sweden
# Garphyttan                               Kilsvägen 2A, 719 40 Garphyttan, Sweden
# Gunnebo                                 Västrumsvägen 15, 590 93 Gunnebo, Sweden
# Sveriges                                     Gruvvägen 2, 760 49 Herräng, Sweden
# Tabergs                                 Bergslagsvägen 24, 562 41 Taberg, Sweden
# Värmland                         GUNNERUDSTORP 30, 686 96 Östra Ämtervik, Sweden
# Grängesberg                         Kopparbergsvägen, 772 31 Grängesberg, Sweden
# Adolf Fredriks skrädhus                                                      NaN
# Stora Kopparbergs                        Kyrkogårdsgränd 2, 791 33 Falun, Sweden
# Finspångs                                  Igelfors 341, 612 95 Finspång, Sweden
# Berga                                         Poststraße 4, 07980 Berga, Germany
# Malmö                                     Baltzarsgatan 31, 211 36 Malmö, Sweden
# Stortägtsgruvan                                                              NaN
# Strömsholms                        Erikslundsvägen 4A, 734 94 Strömsholm, Sweden
# Lund                               Stora Gråbrödersgatan 15, 222 22 Lund, Sweden
# Finspång                                Kalkugnsvägen 1, 612 30 Finspång, Sweden
# Tyskland                            Höngedaer Weg 8E, 99986 Niederdorla, Germany
# Norden                         20850 Donner Pass Rd, Soda Springs, CA 95728, USA
# Leipzig                                Thomaskirchhof 19, 04109 Leipzig, Germany
# Åmmeberg                                Långängsvägen 4, 696 75 Åmmeberg, Sweden
# Närke                               Koppartorpsvägen 48, 611 95 Nyköping, Sweden
# Timsälven                                                                    NaN
# Sala gruva                      Drottning Christinas väg 9A, 733 36 Sala, Sweden
# Sandvikens                                  SANDVIKEN 1, 930 90 Arjeplog, Sweden
# Rejmyre                                      Skolvägen 1, 610 14 Rejmyre, Sweden
# ...                                                                          ...
# öregrund                                                                     NaN
# Skärplinge                                                                   NaN
# Åkerby bruk                                                                  NaN
# Löfsta                                                                       NaN
# Harnäsviken                                                                  NaN
# Mörkö                                                                        NaN
# Hasslö                                                                       NaN
# Falsterbo                                                                    NaN
# Norrlandskusten                                                              NaN
# Upplandskusten                                                               NaN
# General Electrics forskningsl                                                NaN
# Schenectady. Hans                                                            NaN
# WGY-studion                                                                  NaN
# General Electrics laboratoriu                                                NaN
# Huvudgatan                                                                   NaN
# Bochum                                                                       NaN
# Västtyskland                                                                 NaN
# Ludvika. Exkursioner                                                         NaN
# Karlsholmsbruk                                                               NaN
# Loka brunn                                                                   NaN
# Dalarnas museum                                                              NaN
# PPL/HUM\tAlbany                                                              NaN
# Mark                                                                         NaN
# ROM                                                                          NaN
# Infotech State                                                               NaN
# PPL/HUM\tNyborg                                                              NaN
# Santa Clara                                                                  NaN
# Hallwylska palatset                                                          NaN
# PPL/CRP\tPerstorps                                                           NaN
# Hässelby                                                                     NaN
#
# [2793 rows x 4 columns]
